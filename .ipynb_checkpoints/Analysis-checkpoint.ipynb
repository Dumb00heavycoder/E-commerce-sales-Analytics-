# %% [markdown]
# # E-Commerce-Sales Data Analysis
# ---

# %% [markdown]
# Work flow:-
# 1. Introduction 2. Dataset Overview 3. Data Cleaning 4. Feature Engineering 5. Product Analysis(graphs) 6. Time Analysis(graphs) 7. Business Insights(graphs) 8. Conclusion
#
# ## Data Overview

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('data/Amazon Sale Report.csv', low_memory= False)

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %%
#Changing the data type of date
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# /var/folders/5m/y67y675x3hl3fdklb6p6mlnr0000gn/T/ipykernel_85843/779191431.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
summary = df.describe().drop(columns = ['index', 'ship-postal-code', 'Date'])
summary
# Out:
#                  Qty         Amount
# count  128975.000000  121180.000000
# mean        0.904431     648.561465
# min         0.000000       0.000000
# 25%         1.000000     449.000000
# 50%         1.000000     605.000000
# 75%         1.000000     788.000000
# max        15.000000    5584.000000
# std         0.313354     281.211687

# %%
df.shape
# Out:
# (128975, 24)

# %% [markdown]
# ---
# ## Data Cleaning
#
# ##### Dealing with Na values

# %%
df.isna().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64

# %%
df.isna().mean() * 100
# Out:
# index                  0.000000
# Order ID               0.000000
# Date                   0.000000
# Status                 0.000000
# Fulfilment             0.000000
# Sales Channel          0.000000
# ship-service-level     0.000000
# Style                  0.000000
# SKU                    0.000000
# Category               0.000000
# Size                   0.000000
# ASIN                   0.000000
# Courier Status         5.328164
# Qty                    0.000000
# currency               6.043807
# Amount                 6.043807
# ship-city              0.025586
# ship-state             0.025586
# ship-postal-code       0.025586
# ship-country           0.025586
# promotion-ids         38.110487
# B2B                    0.000000
# fulfilled-by          69.546811
# Unnamed: 22           38.030626
# dtype: float64

# %%
df.drop(columns = ['Unnamed: 22'], inplace = True)

# %% [markdown]
# <mark> Observation 1:- Unamed: 22 is a useless column for this analysis <mark>

# %%
na_amount = df[df['Amount'].isna() == True]
na_amount
# Out:
#          index             Order ID       Date     Status Fulfilment  \
# 8            8  407-5443024-5233168 2022-04-30  Cancelled     Amazon
# 29          29  404-5933402-8801952 2022-04-30  Cancelled   Merchant
# 65          65  171-4137548-0481151 2022-04-30  Cancelled     Amazon
# 84          84  403-9950518-0349133 2022-04-30  Cancelled     Amazon
# 95          95  405-9112089-3379536 2022-04-30  Cancelled     Amazon
# ...        ...                  ...        ...        ...        ...
# 128903  128903  406-3923120-4345139 2022-05-31  Cancelled     Amazon
# 128907  128907  403-6757403-6097100 2022-05-31  Cancelled     Amazon
# 128908  128908  403-6757403-6097100 2022-05-31  Cancelled     Amazon
# 128958  128958  408-9513596-4393945 2022-05-31  Cancelled     Amazon
# 128967  128967  404-5182288-1653947 2022-05-31  Cancelled     Amazon
#
#        Sales Channel  ship-service-level    Style                  SKU  \
# ...

# %%
non_cancel_na_amount = (df['Status'] != 'Cancelled') & (df['Amount'] == 'NaN')
df_non_cancel_na_amount = df[non_cancel_na_amount]
df_non_cancel_na_amount.size
# Out:
# 0

# %% [markdown]
# <mark> Observation 2:- Every order with NaN amount value is a cancelled order <mark>

# %% [markdown]
# ##### Finding and dealing with duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# <mark> Observation 3:- No duplicated values exist <mark>

# %% [markdown]
# ### Conclusion of Data cleaning :-
# - Unamed: 22 column is of no use
# - Every order with NaN amount value is a cancelled order
# - No duplicates exist

# %% [markdown]
# ---
# ## Feature Engeineering
#
# Here I'll be adding 4 new features which will make our analysis much better

# %% [markdown]
# #### <span style="color:red"> Revenue Feature

# %%
df['Revenue'] = df['Amount'] * df['Qty']

# %% [markdown]
# #### <span style="color:red"> Year Feature

# %%
df['Year'] = df['Date'].dt.year

# %% [markdown]
# #### <span style="color:red"> Month Feature

# %%
df['Month'] = df['Date'].dt.month_name()

# %% [markdown]
# #### <span style="color:red"> Order size Feature

# %% [markdown]
# #### Any order with revenue over 30000 is a large order and any order below 30000 is a small order

# %%
df['Order-size'] = df['Revenue'].apply(lambda x: 'Large' if x>3000 else 'Small')

# %% [markdown]
# ---
# ## Product analysis

# %% [markdown]
# #### <span style="color:#F54927"> Category Wise Revenue with graph

# %%
cate_sales = df.groupby('Category')['Revenue'].sum()
cate_sales.sort_values(ascending = False)
# Out:
# Category
# Set              37934434.0
# kurta            20675349.0
# Western Dress    10707932.0
# Top               5242931.0
# Ethnic Dress       762949.0
# Blouse             441259.0
# Bottom             142870.0
# Saree              125767.0
# Dupatta               915.0
# Name: Revenue, dtype: float64

# %%
plt.barh(cate_sales.index, cate_sales.values, log = True, color = '#FFAC1C')
plt.title('Category wise Revenue')
plt.tight_layout()
plt.show()

# %% [markdown]
#  #### <span style="color:#F54927"> Category wise quantity with graph

# %%
cat_unit = df.groupby('Category')['Qty'].sum()
cat_unit.sort_values(ascending = False)
# Out:
# Category
# Set              45289
# kurta            45045
# Western Dress    13943
# Top               9903
# Ethnic Dress      1053
# Blouse             863
# Bottom             398
# Saree              152
# Dupatta              3
# Name: Qty, dtype: int64

# %%
plt.barh(cat_unit.index, cat_unit.values, color = '#FFAC1C', log = True)
plt.title('Category wise Units sold')
plt.tight_layout()
plt.show()

# %% [markdown]
# <mark> Observation 1:- Revenue of Kurta-category is less than the revenue of Set-category but the amount sold for kurta-category and set are almost same which means that Set-category are being sold at a much higher price than kurta-category <mark>

# %% [markdown]
# #### <span style="color:#F54927"> Most expensive SKU

# %%
#most expensive skus
Skus_amount= df.groupby('SKU')['Amount'].sum().sort_values(ascending = False)
Skus_amount.head(3)
# Out:
# SKU
# J0230-SKD-M     527699.20
# JNE3797-KR-L    524581.77
# J0230-SKD-S     479937.14
# Name: Amount, dtype: float64

# %% [markdown]
# #### <span style="color:#F54927"> SKU with most items

# %%
#Sku with most items
Sku_count = df['SKU'].value_counts()
Sku_count.head(5)
# Out:
# SKU
# JNE3797-KR-L    773
# JNE3797-KR-M    657
# JNE3797-KR-S    587
# JNE3405-KR-L    535
# J0230-SKD-M     507
# Name: count, dtype: int64

# %% [markdown]
# #### <span style="color:#F54927"> Amount of items in top 3 SKU

# %%
#Amount of items in top 3 most expensive Sku
for SKU in Skus_amount.head(3).index:
    print(f"Number of items {SKU}:",int(df['SKU'].value_counts()[SKU]))
# Out:
# Number of items J0230-SKD-M: 507
# Number of items JNE3797-KR-L: 773
# Number of items J0230-SKD-S: 452

# %% [markdown]
# #### Here we notice a possibility of expensive Sku not does not equal to more items in sku. Lets check this possibility with graphs

# %% [markdown]
# #### <span style="color:#F54927">Do the most expensive SKUs also have a high number of items sold, or are they expensive just because of price?

# %%
x= Skus_amount.head(15).index
y = Skus_amount.head(15)
plt.barh(x,y, color = '#FFAC1C')
plt.title('Most expensive SKU')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Just because it is hard to remember the Sku names. We will use Sku_amount variable for easier comparison

# %%
y =[]
for SKU in Skus_amount.head(15).index:
    y.append(int(df['SKU'].value_counts()[SKU]))
x= Skus_amount.head(15).index
plt.barh(x,y, color = '#FFAC1C')
plt.title('Number of items contained by most expensive SKU')
plt.tight_layout()
plt.show()

# %% [markdown]
# <mark> Observation 2:- As we can clearly see that the most Expensive SKU (J0230-SKD-M) has fewer items when compared to other expensive SKU. Which means that J0230-SKD-M is only expensive because of the cost. Therefore its not always the items which make an SKU expensive it can also only depend on the cost. <mark>

# %% [markdown]
# #### <span style="color:#F54927"> Find out SKU with high revenue but low volume (to increase their volume for more profit)

# %%
Skus_Revenue= df.groupby('SKU')['Revenue'].sum().sort_values(ascending = False)
Sku_volume = df['SKU'].value_counts().sort_values(ascending = True)
# Out:
# SKU
# SET045-KR-NP-M          1
# SET022-KR-SP-A-XXL      1
# J0085-TP-L              1
# J0152-DR-M              1
# SET449-KR-NP-M          1
#                      ...
# J0230-SKD-M           507
# JNE3405-KR-L          535
# JNE3797-KR-S          587
# JNE3797-KR-M          657
# JNE3797-KR-L          773
# Name: count, Length: 7195, dtype: int64

# %% [markdown]
# #### <span style="color:#F54927"> Find out SKU with low revenue but high volume (to increase their price for profit)
