# %% [markdown]
# # E-Commerce-Sales Data Analysis
# ---

# %% [markdown]
# Work flow:-
# 1. Introduction 2. Dataset Overview 3. Data Cleaning 4. Feature Engineering 5. Product Analysis 6. Customer Analysis 7. Time Analysis 8. Business Insights 9. Conclusion
